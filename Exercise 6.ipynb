# %% [markdown]
# ## **Data Science Tools**
#
# Below is a table listing some commonly used Data Science tools:
#
# | **Tool**            | **Category**               | **Description**                                    |
# |---------------------|----------------------------|----------------------------------------------------|
# | Jupyter Notebook    | Interactive Environment    | Used for writing, running, and documenting code    |
# | Google Col
